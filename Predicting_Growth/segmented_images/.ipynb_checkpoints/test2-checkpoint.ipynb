# %%
import matplotlib.pyplot as plt

# %%
im1=plt.imread('image2019-10-26-07-25-59.jpg')
im2=plt.imread('image2019-11-20-13-29-03.jpg')

# %%
plt.imshow(im1)

# %%
plt.imshow(im2)

# %%
from skimage.color import rgb2gray

# %%
g1=rgb2gray(im1)
plt.imshow(g1,cmap='gray')

# %%
g1=g1[650:2163, 1504:2608]
plt.imshow(g1,cmap='gray')

# %%
g2=rgb2gray(im2)
g2=g2[650:2163, 1504:2608]
plt.imshow(g2,cmap='gray')
